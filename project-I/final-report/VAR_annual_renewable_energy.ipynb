# %% [markdown]
# ### This notebook presented the prediction of annual renewable energy consumption by VAR model

# %%
import pandas as pd
import numpy as np
import math

import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load data

# %%
df = pd.read_csv('data_4.csv',index_col=[0],parse_dates=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 69 entries, 1949-01-01 to 2017-01-01
# Data columns (total 18 columns):
# total-renewable-consumption                              69 non-null float64
# total-renewable-production                               69 non-null float64
# Hydroelectric-power                                      69 non-null float64
# Hydroelectric-power-Con-Pro                              69 non-null float64
# Geothermal_Energy_Consumption_per_Production             69 non-null float64
# Geothermal_Energy_Consumption_by_the_Electric_Power      69 non-null float64
# Solar_per_PV_Energy_Consumption_per_Production           69 non-null float64
# Total_Biomass_Energy_Consumed_by_the_Electric_Power      69 non-null float64
# Total_Biomass_Energy_Production                          69 non-null float64
# Total_Renewable_Energy_Consumed_by_the_Electric_Power    69 non-null float64
# Waste_Consumption_for_Electricity                        69 non-null float64
# Wind_Energy_Consumed_by_the_Electric_Power               69 non-null float64
# Wind_Energy_Consumption_per_Production                   69 non-null float64
# Wood_Consumption_for_Electricity                         69 non-null float64
# Biomass_Exports                                          69 non-null float64
# Biomass_Imports                                          69 non-null float64
# Biofuels_Consumption                                     69 non-null float64
# Biofuels_Production                                      69 non-null float64
# dtypes: float64(18)
# memory usage: 10.2 KB

# %% [markdown]
# ## Important features

# %%
data = df[['total-renewable-consumption','total-renewable-production', 
           'Hydroelectric-power-Con-Pro','Wood_Consumption_for_Electricity']].dropna()

# %%
# Perform Dickey-fuller test  for stationality
from statsmodels.tsa.stattools import adfuller

# %%
data.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000000E8ACC18>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000001A3BB160>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000001A3E55C0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000001A40DA20>],
#       dtype=object)

# %%
for i in data.columns: 
    x = data[i].values
    result = adfuller(x)
    print('\033[1m' + i + '\033[0m')
    print('ADF Statistic:', result[0])
    print('p-value:', result[1])
    print('')
# Out:
# total-renewable-consumption
# ADF Statistic: 1.6563030363669504
# p-value: 0.9980170334569259
#
# total-renewable-production
# ADF Statistic: 1.7198906745307445
# p-value: 0.9981761652300903
#
# Hydroelectric-power-Con-Pro
# ADF Statistic: -2.207806582580489
# p-value: 0.20342432832684604
#
# Wood_Consumption_for_Electricity
# ADF Statistic: 0.3293028900201523
# p-value: 0.9786496577883694

# %% [markdown]
# ## Transform data

# %%
diff = data.diff().dropna()
diff.head()
# Out:
#             total-renewable-consumption  total-renewable-production  \
# Year
# 1950-01-01                        3.734                       3.734
# 1951-01-01                      -19.254                     -19.254
# 1952-01-01                      -18.283                     -18.283
# 1953-01-01                     -108.721                    -108.721
# 1954-01-01                      -77.361                     -77.361
#
#             Hydroelectric-power-Con-Pro  Wood_Consumption_for_Electricity
# Year
# 1950-01-01                       -9.311                            -0.337
# 1951-01-01                        8.384                            -0.135
# 1952-01-01                       42.017                             1.104
# 1953-01-01                      -52.953                            -1.416
# 1954-01-01                      -53.087                            -1.810

# %%
for i in diff.columns: 
    x = diff[i].values
    result = adfuller(x)
    print('\033[1m' + i + '\033[0m')
    print('ADF Statistic:', result[0])
    print('p-value:', result[1])
    print('')
# Out:
# total-renewable-consumption
# ADF Statistic: -7.625934809150868
# p-value: 2.0687514978521278e-11
#
# total-renewable-production
# ADF Statistic: -7.541929515234531
# p-value: 3.3603515988430476e-11
#
# Hydroelectric-power-Con-Pro
# ADF Statistic: -9.008804863613681
# p-value: 6.206056962658665e-15
#
# Wood_Consumption_for_Electricity
# ADF Statistic: -6.983187582822547
# p-value: 8.092847400389742e-10

# %%
diff = diff.dropna()
diff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 68 entries, 1950-01-01 to 2017-01-01
# Data columns (total 4 columns):
# total-renewable-consumption         68 non-null float64
# total-renewable-production          68 non-null float64
# Hydroelectric-power-Con-Pro         68 non-null float64
# Wood_Consumption_for_Electricity    68 non-null float64
# dtypes: float64(4)
# memory usage: 2.7 KB

# %%
diff.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000001B58A9B0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000001B5F5710>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000001B61BB38>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000001B643F60>],
#       dtype=object)

# %% [markdown]
# ## Split data

# %%
x_train = diff.iloc[:58,:]
y_train = diff.iloc[:58,0]

x_test = diff.iloc[58:,:]
y_test = diff.iloc[58:,0]

# %%
x_train.shape
# Out:
# (58, 4)

# %%
x_test.shape
# Out:
# (10, 4)

# %% [markdown]
# ## Build model

# %%
import statsmodels.api as sm
from statsmodels.tsa.api import VAR

# %%
# make a VAR model
model = VAR(x_train,freq='AS-JAN')

# %%
model.select_order(3).summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
res = model.fit(maxlags=3, ic='aic')

# %%
lag_order = res.k_ar
lag_order
# Out:
# 2

# %% [markdown]
# ## Predict and Compare with test set

# %%
res.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Mon, 24, Dec, 2018
# Time:                     21:56:05
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                    30.8604
# Nobs:                     56.0000    HQIC:                   30.0632
# Log likelihood:          -1109.48    FPE:                6.94934e+12
# AIC:                      29.5584    Det(Omega_mle):     3.82862e+12
# --------------------------------------------------------------------
# Results for equation total-renewable-consumption
# ======================================================================================================
#                                          coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------------------
# const                                      56.675865        48.184601            1.176           0.240
# L1.total-renewable-consumption             -8.898166         9.157115           -0.972           0.331
# L1.total-renewable-production               9.055351         9.324795            0.971           0.331
# L1.Hydroelectric-power-Con-Pro             -0.212350         0.462742           -0.459           0.646
# L1.Wood_Consumption_for_Electricity        -2.651209         3.410046           -0.777           0.437
# L2.total-renewable-consumption             13.828726        23.275348            0.594           0.552
# L2.total-renewable-production             -13.255693        23.395027           -0.567           0.571
# L2.Hydroelectric-power-Con-Pro             -0.725737         0.435798           -1.665           0.096
# L2.Wood_Consumption_for_Electricity        -0.329352         3.781181           -0.087           0.931
# ======================================================================================================
#
# Results for equation total-renewable-production
# ======================================================================================================
#                                          coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------------------
# const                                      56.674088        48.110928            1.178           0.239
# L1.total-renewable-consumption             -7.886194         9.143115           -0.863           0.388
# L1.total-renewable-production               8.031563         9.310537            0.863           0.388
# L1.Hydroelectric-power-Con-Pro             -0.200973         0.462034           -0.435           0.664
# L1.Wood_Consumption_for_Electricity        -2.703005         3.404832           -0.794           0.427
# L2.total-renewable-consumption             12.175625        23.239760            0.524           0.600
# L2.total-renewable-production             -11.599255        23.359257           -0.497           0.619
# L2.Hydroelectric-power-Con-Pro             -0.729503         0.435132           -1.677           0.094
# L2.Wood_Consumption_for_Electricity        -0.405215         3.775399           -0.107           0.915
# ======================================================================================================
#
# Results for equation Hydroelectric-power-Con-Pro
# ======================================================================================================
#                                          coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------------------
# const                                      21.529324        40.434509            0.532           0.594
# L1.total-renewable-consumption            -11.715595         7.684270           -1.525           0.127
# L1.total-renewable-production              11.613920         7.824979            1.484           0.138
# L1.Hydroelectric-power-Con-Pro              0.041591         0.388314            0.107           0.915
# L1.Wood_Consumption_for_Electricity         1.095477         2.861568            0.383           0.702
# L2.total-renewable-consumption              4.511649        19.531702            0.231           0.817
# L2.total-renewable-production              -3.923085        19.632132           -0.200           0.842
# L2.Hydroelectric-power-Con-Pro             -0.726748         0.365704           -1.987           0.047
# L2.Wood_Consumption_for_Electricity        -2.880852         3.173009           -0.908           0.364
# ======================================================================================================
#
# Results for equation Wood_Consumption_for_Electricity
# ======================================================================================================
#                                          coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------------------
# const                                       2.894113         2.012346            1.438           0.150
# L1.total-renewable-consumption             -0.002708         0.382431           -0.007           0.994
# L1.total-renewable-production               0.018281         0.389434            0.047           0.963
# L1.Hydroelectric-power-Con-Pro             -0.022443         0.019326           -1.161           0.246
# L1.Wood_Consumption_for_Electricity         0.150953         0.142415            1.060           0.289
# L2.total-renewable-consumption              0.540972         0.972055            0.557           0.578
# L2.total-renewable-production              -0.559749         0.977053           -0.573           0.567
# L2.Hydroelectric-power-Con-Pro             -0.001174         0.018200           -0.065           0.949
# L2.Wood_Consumption_for_Electricity         0.134380         0.157914            0.851           0.395
# ======================================================================================================
#
# Correlation matrix of residuals
#                                     total-renewable-consumption  total-renewable-production  Hydroelectric-power-Con-Pro  Wood_Consumption_for_Electricity
# total-renewable-consumption                            1.000000                    0.999880                     0.923689                          0.300056
# total-renewable-production                             0.999880                    1.000000                     0.925126                          0.303983
# Hydroelectric-power-Con-Pro                            0.923689                    0.925126                     1.000000                          0.238938
# Wood_Consumption_for_Electricity                       0.300056                    0.303983                     0.238938                          1.000000

# %%
pred = res.forecast(x_train.values[-lag_order:], 10)
pred
# Out:
# array([[ 1.07428577e+03,  9.70037845e+02,  7.34347650e+02,
#          2.49360972e+01],
#        [-1.20251405e+03, -1.03777372e+03, -1.16094559e+03,
#         -1.30127338e+01],
#        [ 3.09679016e+03,  2.75605151e+03,  2.43027315e+03,
#          5.19388711e+01],
#        [-5.22183261e+03, -4.61039485e+03, -4.56551865e+03,
#         -7.18305329e+01],
#        [ 1.04430355e+04,  9.26336050e+03,  8.62865968e+03,
#          1.61078639e+02],
#        [-1.90038448e+04, -1.68116545e+04, -1.61527805e+04,
#         -2.73873605e+02],
#        [ 3.63831708e+04,  3.22298730e+04,  3.04813013e+04,
#          5.43944890e+02],
#        [-6.78847780e+04, -6.00945610e+04, -5.73073286e+04,
#         -9.96498309e+02],
#        [ 1.28343527e+05,  1.13655433e+05,  1.07911913e+05,
#          1.90280538e+03],
#        [-2.40982007e+05, -2.13362987e+05, -2.03039044e+05,
#         -3.55407613e+03]])

# %%
res.plot_acorr()
plt.show()

# %%
res.plot_forecast(10)
plt.show()

# %%
y_pre = pd.DataFrame(pred).iloc[:,0]
y_pre
# Out:
# 0      1074.285767
# 1     -1202.514049
# 2      3096.790164
# 3     -5221.832607
# 4     10443.035479
# 5    -19003.844783
# 6     36383.170843
# 7    -67884.777972
# 8    128343.526789
# 9   -240982.006503
# Name: 0, dtype: float64

# %%
plt.plot(y_test.index,y_pre.values)
y_test.plot()
plt.legend(['fit','test'])

# %%
from sklearn.metrics import mean_squared_error

# %%
math.sqrt(mean_squared_error(y_pre.values, y_test.values))
# Out:
# 90124.89505708798

# %% [markdown]
# ## Prediction for next 5 years
# Use this model for the whole data and make a prediction

# %%
model_1 = VAR(diff,freq='AS-JAN')
model_1.select_order(3).summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
result_1 = model_1.fit(maxlags=3, ic='aic')

# %%
lag_order = result_1.k_ar
lag_order
# Out:
# 3

# %%
result_1.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Mon, 24, Dec, 2018
# Time:                     21:56:10
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                    34.3501
# Nobs:                     65.0000    HQIC:                   33.2969
# Log likelihood:          -1376.77    FPE:                1.48626e+14
# AIC:                      32.6106    Det(Omega_mle):     7.16756e+13
# --------------------------------------------------------------------
# Results for equation total-renewable-consumption
# ======================================================================================================
#                                          coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------------------
# const                                      60.334425        51.125740            1.180           0.238
# L1.total-renewable-consumption             -0.810127         2.816177           -0.288           0.774
# L1.total-renewable-production               0.974794         2.757119            0.354           0.724
# L1.Hydroelectric-power-Con-Pro             -0.434192         0.349125           -1.244           0.214
# L1.Wood_Consumption_for_Electricity        -2.315201         3.437433           -0.674           0.501
# L2.total-renewable-consumption             -0.874632         2.971545           -0.294           0.769
# L2.total-renewable-production               1.061444         2.912914            0.364           0.716
# L2.Hydroelectric-power-Con-Pro             -0.329485         0.363865           -0.906           0.365
# L2.Wood_Consumption_for_Electricity        -1.561555         3.394902           -0.460           0.646
# L3.total-renewable-consumption             -3.246350         2.921905           -1.111           0.267
# L3.total-renewable-production               3.769281         2.877553            1.310           0.190
# L3.Hydroelectric-power-Con-Pro             -0.771894         0.344559           -2.240           0.025
# L3.Wood_Consumption_for_Electricity         1.828785         3.334039            0.549           0.583
# ======================================================================================================
#
# Results for equation total-renewable-production
# ======================================================================================================
#                                          coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------------------
# const                                      60.438856        51.738618            1.168           0.243
# L1.total-renewable-consumption             -0.724041         2.849937           -0.254           0.799
# L1.total-renewable-production               0.923104         2.790170            0.331           0.741
# L1.Hydroelectric-power-Con-Pro             -0.477100         0.353310           -1.350           0.177
# L1.Wood_Consumption_for_Electricity        -2.606702         3.478639           -0.749           0.454
# L2.total-renewable-consumption             -0.613240         3.007167           -0.204           0.838
# L2.total-renewable-production               0.762362         2.947833            0.259           0.796
# L2.Hydroelectric-power-Con-Pro             -0.300147         0.368227           -0.815           0.415
# L2.Wood_Consumption_for_Electricity        -1.136849         3.435599           -0.331           0.741
# L3.total-renewable-consumption             -3.354750         2.956932           -1.135           0.257
# L3.total-renewable-production               3.906532         2.912048            1.342           0.180
# L3.Hydroelectric-power-Con-Pro             -0.811221         0.348690           -2.326           0.020
# L3.Wood_Consumption_for_Electricity         1.602200         3.374007            0.475           0.635
# ======================================================================================================
#
# Results for equation Hydroelectric-power-Con-Pro
# ======================================================================================================
#                                          coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------------------
# const                                      26.796131        44.669146            0.600           0.549
# L1.total-renewable-consumption             -2.460941         2.460526           -1.000           0.317
# L1.total-renewable-production               2.353852         2.408927            0.977           0.329
# L1.Hydroelectric-power-Con-Pro             -0.059060         0.305035           -0.194           0.846
# L1.Wood_Consumption_for_Electricity         1.795627         3.003324            0.598           0.550
# L2.total-renewable-consumption             -0.916950         2.596273           -0.353           0.724
# L2.total-renewable-production               0.871536         2.545046            0.342           0.732
# L2.Hydroelectric-power-Con-Pro             -0.086264         0.317913           -0.271           0.786
# L2.Wood_Consumption_for_Electricity        -2.394201         2.966165           -0.807           0.420
# L3.total-renewable-consumption             -1.304239         2.552902           -0.511           0.609
# L3.total-renewable-production               1.467040         2.514151            0.584           0.560
# L3.Hydroelectric-power-Con-Pro             -0.230706         0.301045           -0.766           0.443
# L3.Wood_Consumption_for_Electricity        -0.527665         2.912989           -0.181           0.856
# ======================================================================================================
#
# Results for equation Wood_Consumption_for_Electricity
# ======================================================================================================
#                                          coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------------------
# const                                       2.763832         2.038174            1.356           0.175
# L1.total-renewable-consumption              0.209606         0.112269            1.867           0.062
# L1.total-renewable-production              -0.203245         0.109915           -1.849           0.064
# L1.Hydroelectric-power-Con-Pro             -0.008428         0.013918           -0.606           0.545
# L1.Wood_Consumption_for_Electricity         0.189709         0.137036            1.384           0.166
# L2.total-renewable-consumption             -0.034929         0.118463           -0.295           0.768
# L2.total-renewable-production               0.041239         0.116126            0.355           0.722
# L2.Hydroelectric-power-Con-Pro             -0.027452         0.014506           -1.893           0.058
# L2.Wood_Consumption_for_Electricity         0.017660         0.135341            0.130           0.896
# L3.total-renewable-consumption             -0.263042         0.116484           -2.258           0.024
# L3.total-renewable-production               0.247702         0.114716            2.159           0.031
# L3.Hydroelectric-power-Con-Pro              0.022077         0.013736            1.607           0.108
# L3.Wood_Consumption_for_Electricity         0.112889         0.132915            0.849           0.396
# ======================================================================================================
#
# Correlation matrix of residuals
#                                     total-renewable-consumption  total-renewable-production  Hydroelectric-power-Con-Pro  Wood_Consumption_for_Electricity
# total-renewable-consumption                            1.000000                    0.998727                     0.914998                          0.182686
# total-renewable-production                             0.998727                    1.000000                     0.914161                          0.173040
# Hydroelectric-power-Con-Pro                            0.914998                    0.914161                     1.000000                          0.084256
# Wood_Consumption_for_Electricity                       0.182686                    0.173040                     0.084256                          1.000000

# %%
result_1.plot_forecast(5)
plt.show()

# %%
predicted = result_1.forecast(diff.values[-lag_order:], 5)
predicted
# Out:
# array([[228.44666688, 198.54702835,  95.56808362, -10.05667331],
#        [526.22360325, 522.43490324,  33.41988974,  11.39942235],
#        [504.91557189, 535.54446518,  99.06333104,  13.64600492],
#        [ 78.80131431,  74.59092311, -17.31658235,  -5.98348933],
#        [419.41263501, 416.20816961,  27.65865774,  -1.88370246]])

# %%
y_fore = pd.DataFrame(predicted).iloc[:,0]

# %%
d = pd.date_range('2017-01-01', '2022-01-01',freq='Y')
year = d + pd.offsets.MonthBegin(1)
year
# Out:
# DatetimeIndex(['2018-01-01', '2019-01-01', '2020-01-01', '2021-01-01',
#                '2022-01-01'],
#               dtype='datetime64[ns]', freq='AS-JAN')

# %%
pd.DataFrame(index=year,data=y_fore.values.cumsum()+data.iloc[-1,0]).plot()
data['total-renewable-consumption'].plot()
plt.legend(['prediction','data'])
plt.ylabel('total-renewable-energy-consumption')
plt.show()

# %%
y_next5year = pd.DataFrame(index=year,data=y_fore.values.cumsum()+data.iloc[-1,0],columns=['Predicted-values'])
y_next5year
# Out:
#             Predicted-values
# 2018-01-01      11306.844667
# 2019-01-01      11833.068270
# 2020-01-01      12337.983842
# 2021-01-01      12416.785156
# 2022-01-01      12836.197791

# %%
#y_next5year.to_csv('Predicted-renewable-energy.csv')
