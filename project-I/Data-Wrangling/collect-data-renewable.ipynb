# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Total_Renewable_Energy_Consumption_Annual

# %%
df1 = pd.read_csv('renew/1-Total_Renewable_Energy_Consumption_Annual.csv',index_col='Year',skiprows=4,parse_dates=True)
df1.columns = ['total-renewable-consumption']
df1 = df1.sort_index()
df1.head()
# Out:
#             total-renewable-consumption
# Year
# 1949-01-01                     2973.984
# 1950-01-01                     2977.718
# 1951-01-01                     2958.464
# 1952-01-01                     2940.181
# 1953-01-01                     2831.460

# %%
df1.plot()

# %%
df2 = pd.read_csv('renew/2-Total_Renewable_Energy_Production_Annual.csv',index_col='Year',skiprows=4,parse_dates=True)
df2.columns = ['total-renewable-production']
df2 = df2.sort_index()
df2.head()
# Out:
#             total-renewable-production
# Year
# 1949-01-01                    2973.984
# 1950-01-01                    2977.718
# 1951-01-01                    2958.464
# 1952-01-01                    2940.181
# 1953-01-01                    2831.460

# %%
df2.plot()

# %%
df3 = pd.read_csv('renew/3-Conventional_Hydroelectric_Power_Consumed_by_the_Electric_Power_Sector_Annual.csv',index_col='Year',skiprows=4,parse_dates=True)
df3.columns = ['Hydroelectric-power']
df3 = df3.sort_index()
df3.head()
# Out:
#             Hydroelectric-power
# Year
# 1949-01-01             1349.185
# 1950-01-01             1346.015
# 1951-01-01             1360.698
# 1952-01-01             1404.274
# 1953-01-01             1356.353

# %%
df3.plot()

# %%
df4 = pd.read_csv('renew/4-Hydroelectric_Power_Consumption_per_Production_Annual.csv',index_col='Year',skiprows=4,parse_dates=True)
df4.columns = ['Hydroelectric-power-Con-Pro']
df4 = df4.sort_index()
df4.head()
# Out:
#             Hydroelectric-power-Con-Pro
# Year
# 1949-01-01                     1424.722
# 1950-01-01                     1415.411
# 1951-01-01                     1423.795
# 1952-01-01                     1465.812
# 1953-01-01                     1412.859

# %%
df4.plot()

# %%
df5 = pd.read_csv('renew/5-Geothermal_Energy_Consumption_per_Production_Annual.csv',index_col='Year',skiprows=4,parse_dates=True)
df5.columns = ['Geothermal_Energy_Consumption_per_Production']
df5 = df5.sort_index()
df5 = df5.fillna(0)
df5.head()
# Out:
#             Geothermal_Energy_Consumption_per_Production
# Year
# 1949-01-01                                           0.0
# 1950-01-01                                           0.0
# 1951-01-01                                           0.0
# 1952-01-01                                           0.0
# 1953-01-01                                           0.0

# %%
df5.plot()

# %%
df6 = pd.read_csv('renew/6-Geothermal_Energy_Consumed_by_the_Electric_Power_Sector_Annual.csv',index_col='Year',skiprows=4,parse_dates=True)
df6.columns = ['Geothermal_Energy_Consumption_by_the_Electric_Power']
df6 = df6.sort_index()
df6 = df6.fillna(0)
df6.head()
# Out:
#             Geothermal_Energy_Consumption_by_the_Electric_Power
# Year
# 1949-01-01                                                0.0
# 1950-01-01                                                0.0
# 1951-01-01                                                0.0
# 1952-01-01                                                0.0
# 1953-01-01                                                0.0

# %%
df6.plot()

# %%
df7 = pd.read_csv('renew/7-Solar_per_PV_Energy_Consumption_per_Production_Annual.csv',index_col='Year',skiprows=4,parse_dates=True)
df7.columns = ['Solar_per_PV_Energy_Consumption_per_Production']
df7 = df7.sort_index()
df7 = df7.fillna(0)
df7.head()
# Out:
#             Solar_per_PV_Energy_Consumption_per_Production
# Year
# 1949-01-01                                             0.0
# 1950-01-01                                             0.0
# 1951-01-01                                             0.0
# 1952-01-01                                             0.0
# 1953-01-01                                             0.0

# %%
df7.plot()

# %%
df8 = pd.read_csv('renew/8-Total_Biomass_Energy_Consumed_by_the_Electric_Power_Sector_Annual.csv',index_col='Year',skiprows=4,parse_dates=True)
df8.columns = ['Total_Biomass_Energy_Consumed_by_the_Electric_Power']
df8 = df8.sort_index()
df8.head()
# Out:
#             Total_Biomass_Energy_Consumed_by_the_Electric_Power
# Year
# 1949-01-01                                              5.803
# 1950-01-01                                              5.466
# 1951-01-01                                              5.331
# 1952-01-01                                              6.435
# 1953-01-01                                              5.019

# %%
df8.plot()

# %%
df9 = pd.read_csv('renew/9-Total_Biomass_Energy_Production_Annual.csv',index_col='Year',skiprows=4,parse_dates=True)
df9.columns = ['Total_Biomass_Energy_Production']
df9 = df9.sort_index()
df9.head()
# Out:
#             Total_Biomass_Energy_Production
# Year
# 1949-01-01                         1549.262
# 1950-01-01                         1562.307
# 1951-01-01                         1534.669
# 1952-01-01                         1474.369
# 1953-01-01                         1418.601

# %%
df9.plot()

# %%
df10 = pd.read_csv('renew/10-Total_Renewable_Energy_Consumed_by_the_Electric_Power_Sector_Annual.csv',index_col='Year',skiprows=4,parse_dates=True)
df10.columns = ['Total_Renewable_Energy_Consumed_by_the_Electric_Power']
df10 = df10.sort_index()
df10.head()
# Out:
#             Total_Renewable_Energy_Consumed_by_the_Electric_Power
# Year
# 1949-01-01                                           1354.988
# 1950-01-01                                           1351.481
# 1951-01-01                                           1366.029
# 1952-01-01                                           1410.709
# 1953-01-01                                           1361.372

# %%
df10.plot()

# %%
df11 = pd.read_csv('renew/11-Waste_Consumption_for_Electricity_Generation_and_Useful_Thermal_Output_Electric_Power_Sector_Annual.csv',index_col='Year',skiprows=4,parse_dates=True)
df11.columns = ['Waste_Consumption_for_Electricity']
df11 = df11.sort_index()
df11 = df11.fillna(0)
df11.head()
# Out:
#             Waste_Consumption_for_Electricity
# Year
# 1949-01-01                                0.0
# 1950-01-01                                0.0
# 1951-01-01                                0.0
# 1952-01-01                                0.0
# 1953-01-01                                0.0

# %%
df11.plot()

# %%
df12 = pd.read_csv('renew/12-Wind_Energy_Consumed_by_the_Electric_Power_Sector_Annual.csv',index_col='Year',skiprows=4,parse_dates=True)
df12.columns = ['Wind_Energy_Consumed_by_the_Electric_Power']
df12 = df12.sort_index()
df12 = df12.fillna(0)
df12.head()
# Out:
#             Wind_Energy_Consumed_by_the_Electric_Power
# Year
# 1949-01-01                                         0.0
# 1950-01-01                                         0.0
# 1951-01-01                                         0.0
# 1952-01-01                                         0.0
# 1953-01-01                                         0.0

# %%
df12.plot()

# %%
df13 = pd.read_csv('renew/13-Wind_Energy_Consumption_per_Production_Annual.csv',index_col='Year',skiprows=4,parse_dates=True)
df13.columns = ['Wind_Energy_Consumption_per_Production']
df13 = df13.sort_index()
df13 = df13.fillna(0)
df13.head()
# Out:
#             Wind_Energy_Consumption_per_Production
# Year
# 1949-01-01                                     0.0
# 1950-01-01                                     0.0
# 1951-01-01                                     0.0
# 1952-01-01                                     0.0
# 1953-01-01                                     0.0

# %%
df13.plot()

# %%
df14 = pd.read_csv('renew/14-Wood_Consumption_for_Electricity_Generation_and_Useful_Thermal_Output_Electric_Power_Sector_Annual.csv',index_col='Year',skiprows=4,parse_dates=True)
df14.columns = ['Wood_Consumption_for_Electricity']
df14 = df14.sort_index()
df14.head()
# Out:
#             Wood_Consumption_for_Electricity
# Year
# 1949-01-01                             5.803
# 1950-01-01                             5.466
# 1951-01-01                             5.331
# 1952-01-01                             6.435
# 1953-01-01                             5.019

# %%
df14.plot()

# %%
df15 = pd.read_csv('renew/15-Biomass_Exports_Annual.csv',index_col='Year',skiprows=4,parse_dates=True)
df15.columns = ['Biomass_Exports']
df15 = df15.sort_index()
df15 = df15.fillna(0)
df15.head()
# Out:
#             Biomass_Exports
# Year
# 1949-01-01              0.0
# 1950-01-01              0.0
# 1951-01-01              0.0
# 1952-01-01              0.0
# 1953-01-01              0.0

# %%
df15.plot()

# %%
df16 = pd.read_csv('renew/16-Biomass_Imports_Annual.csv',index_col='Year',skiprows=4,parse_dates=True)
df16.columns = ['Biomass_Imports']
df16 = df16.sort_index()
df16 = df16.fillna(0)
df16.head()
# Out:
#             Biomass_Imports
# Year
# 1949-01-01              0.0
# 1950-01-01              0.0
# 1951-01-01              0.0
# 1952-01-01              0.0
# 1953-01-01              0.0

# %%
df16.plot()

# %%
df17 = pd.read_csv('renew/17-Biofuels_Consumption_Annual.csv',index_col='Year',skiprows=4,parse_dates=True)
df17.columns = ['Biofuels_Consumption']
df17 = df17.sort_index()
df17 = df17.fillna(0)
df17.head()
# Out:
#             Biofuels_Consumption
# Year
# 1949-01-01                   0.0
# 1950-01-01                   0.0
# 1951-01-01                   0.0
# 1952-01-01                   0.0
# 1953-01-01                   0.0

# %%
df17.plot()

# %%
df18 = pd.read_csv('renew/18-Biofuels_Production_Annual.csv',index_col='Year',skiprows=4,parse_dates=True)
df18.columns = ['Biofuels_Production']
df18 = df18.sort_index()
df18 = df18.fillna(0)
df18.head()
# Out:
#             Biofuels_Production
# Year
# 1949-01-01                  0.0
# 1950-01-01                  0.0
# 1951-01-01                  0.0
# 1952-01-01                  0.0
# 1953-01-01                  0.0

# %%
df18.plot()

# %% [markdown]
# # Data

# %%
data = pd.concat((df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18),axis=1)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 69 entries, 1949-01-01 to 2017-01-01
# Freq: AS-JAN
# Data columns (total 18 columns):
# total-renewable-consumption                              69 non-null float64
# total-renewable-production                               69 non-null float64
# Hydroelectric-power                                      69 non-null float64
# Hydroelectric-power-Con-Pro                              69 non-null float64
# Geothermal_Energy_Consumption_per_Production             69 non-null float64
# Geothermal_Energy_Consumption_by_the_Electric_Power      69 non-null float64
# Solar_per_PV_Energy_Consumption_per_Production           69 non-null float64
# Total_Biomass_Energy_Consumed_by_the_Electric_Power      69 non-null float64
# Total_Biomass_Energy_Production                          69 non-null float64
# Total_Renewable_Energy_Consumed_by_the_Electric_Power    69 non-null float64
# Waste_Consumption_for_Electricity                        69 non-null float64
# Wind_Energy_Consumed_by_the_Electric_Power               69 non-null float64
# Wind_Energy_Consumption_per_Production                   69 non-null float64
# Wood_Consumption_for_Electricity                         69 non-null float64
# Biomass_Exports                                          69 non-null float64
# Biomass_Imports                                          69 non-null float64
# Biofuels_Consumption                                     69 non-null float64
# Biofuels_Production                                      69 non-null float64
# dtypes: float64(18)
# memory usage: 10.2 KB

# %%
data.head()
# Out:
#             total-renewable-consumption  total-renewable-production  \
# Year
# 1949-01-01                     2973.984                    2973.984
# 1950-01-01                     2977.718                    2977.718
# 1951-01-01                     2958.464                    2958.464
# 1952-01-01                     2940.181                    2940.181
# 1953-01-01                     2831.460                    2831.460
#
#             Hydroelectric-power  Hydroelectric-power-Con-Pro  \
# Year
# 1949-01-01             1349.185                     1424.722
# 1950-01-01             1346.015                     1415.411
# 1951-01-01             1360.698                     1423.795
# 1952-01-01             1404.274                     1465.812
# 1953-01-01             1356.353                     1412.859
#
#             Geothermal_Energy_Consumption_per_Production  \
# Year
# 1949-01-01                                           0.0
# 1950-01-01                                           0.0
# 1951-01-01                                           0.0
# 1952-01-01                                           0.0
# 1953-01-01                                           0.0
#
#             Geothermal_Energy_Consumption_by_the_Electric_Power  \
# Year
# 1949-01-01                                                0.0
# 1950-01-01                                                0.0
# 1951-01-01                                                0.0
# 1952-01-01                                                0.0
# 1953-01-01                                                0.0
#
#             Solar_per_PV_Energy_Consumption_per_Production  \
# Year
# 1949-01-01                                             0.0
# 1950-01-01                                             0.0
# 1951-01-01                                             0.0
# 1952-01-01                                             0.0
# 1953-01-01                                             0.0
#
#             Total_Biomass_Energy_Consumed_by_the_Electric_Power  \
# Year
# 1949-01-01                                              5.803
# 1950-01-01                                              5.466
# 1951-01-01                                              5.331
# 1952-01-01                                              6.435
# 1953-01-01                                              5.019
#
#             Total_Biomass_Energy_Production  \
# Year
# 1949-01-01                         1549.262
# 1950-01-01                         1562.307
# 1951-01-01                         1534.669
# 1952-01-01                         1474.369
# 1953-01-01                         1418.601
#
#             Total_Renewable_Energy_Consumed_by_the_Electric_Power  \
# Year
# 1949-01-01                                           1354.988
# 1950-01-01                                           1351.481
# 1951-01-01                                           1366.029
# 1952-01-01                                           1410.709
# 1953-01-01                                           1361.372
#
#             Waste_Consumption_for_Electricity  \
# Year
# 1949-01-01                                0.0
# 1950-01-01                                0.0
# 1951-01-01                                0.0
# 1952-01-01                                0.0
# 1953-01-01                                0.0
#
#             Wind_Energy_Consumed_by_the_Electric_Power  \
# Year
# 1949-01-01                                         0.0
# 1950-01-01                                         0.0
# 1951-01-01                                         0.0
# 1952-01-01                                         0.0
# 1953-01-01                                         0.0
#
#             Wind_Energy_Consumption_per_Production  \
# Year
# 1949-01-01                                     0.0
# 1950-01-01                                     0.0
# 1951-01-01                                     0.0
# 1952-01-01                                     0.0
# 1953-01-01                                     0.0
#
#             Wood_Consumption_for_Electricity  Biomass_Exports  \
# Year
# 1949-01-01                             5.803              0.0
# 1950-01-01                             5.466              0.0
# 1951-01-01                             5.331              0.0
# 1952-01-01                             6.435              0.0
# 1953-01-01                             5.019              0.0
#
#             Biomass_Imports  Biofuels_Consumption  Biofuels_Production
# Year
# 1949-01-01              0.0                   0.0                  0.0
# 1950-01-01              0.0                   0.0                  0.0
# 1951-01-01              0.0                   0.0                  0.0
# 1952-01-01              0.0                   0.0                  0.0
# 1953-01-01              0.0                   0.0                  0.0

# %%
data.plot(subplots=True,figsize=(8,25))
plt.tight_layout()
plt.legend(loc='best')
plt.show()

# %%
#data.to_csv('data_4.csv')
